# %%
a = "./Dataset/Nao Frontal - Mais Brilho/"

a = a.split('/')

a = a[2]
a = a.split(' - ')
print(repr(a[0]))

if(a[0] == "Nao Frontal"):
    print("Aquele ta quebrado")
# Out:
# 'Nao Frontal'
# Aquele ta quebrado

# %%
# %run Utils.ipynb

# %%
paths = [defaultPaths, noisePaths, moreBrightPaths, lessBrightPaths]

for i in paths:
    for each in i:
        for count in range(30):
            print(each[0] + each[1][count])
# Out:
# ../Dataset/Frontal/real_00006.jpg
# ../Dataset/Frontal/real_00015.jpg
# ../Dataset/Frontal/real_00080.jpg
# ../Dataset/Frontal/real_00107.jpg
# ../Dataset/Frontal/real_00135.jpg
# ../Dataset/Frontal/real_00216.jpg
# ../Dataset/Frontal/real_00244.jpg
# ../Dataset/Frontal/real_00252.jpg
# ../Dataset/Frontal/real_00256.jpg
# ../Dataset/Frontal/real_00260.jpg
# ../Dataset/Frontal/real_00290.jpg
# ../Dataset/Frontal/real_00304.jpg
# ../Dataset/Frontal/real_00337.jpg
# ../Dataset/Frontal/real_00367.jpg
# ../Dataset/Frontal/real_00396.jpg
# ../Dataset/Frontal/real_00397.jpg
# ../Dataset/Frontal/real_00432.jpg
# ../Dataset/Frontal/real_00524.jpg
# ../Dataset/Frontal/real_00551.jpg
# ../Dataset/Frontal/real_00558.jpg
# ../Dataset/Frontal/real_00562.jpg
# ../Dataset/Frontal/real_00567.jpg
# ../Dataset/Frontal/real_00606.jpg
# ../Dataset/Frontal/real_00624.jpg
# ../Dataset/Frontal/real_00693.jpg
# ../Dataset/Frontal/real_00760.jpg
# ../Dataset/Frontal/real_00820.jpg
# ...

# %%
import numpy as np

# %%
np.random.normal(0, 1, 1000)
# Out:
# array([ 3.20843124e-01, -3.82179665e-01,  2.16534943e+00,  1.11361066e-01,
#        -1.27751102e+00, -5.08846055e-01,  3.20707669e-01, -1.63970249e-01,
#        -2.24236167e+00, -3.11684358e-01, -8.69197757e-01,  2.32665717e-01,
#        -1.59685401e-01,  1.61909827e+00,  4.46268316e-01, -1.24204189e+00,
#        -6.53166224e-01,  2.01741483e+00,  1.66645053e+00,  1.01322179e+00,
#         1.16663925e+00,  2.47878822e-01,  1.40398193e+00,  7.99834625e-01,
#        -7.70744674e-01, -4.13133522e-01,  1.39792083e+00, -1.32921081e-01,
#        -2.57792336e-01, -2.86828480e+00, -1.32467042e+00,  2.39428626e-01,
#         3.28314106e-01, -6.78634454e-01,  1.20017518e+00, -3.29964637e-01,
#        -1.82491486e+00, -7.17547001e-01, -1.85241654e-01, -6.79511083e-01,
#         3.62939842e-01,  5.39779043e-01, -5.39487553e-01,  8.48285995e-01,
#         1.11659188e+00, -1.07541717e+00, -4.54760740e-01, -4.12241685e-01,
# ...
